# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import MinMaxScaler,StandardScaler
from sklearn.preprocessing import LabelEncoder,OrdinalEncoder

# %%
df=pd.read_csv('/content/drive/MyDrive/diabetes (1).csv')
df.head()
# Out:
#     Age Gender  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0  50.0   Male      148             72             35        0  33.6
# 1  31.0   Male       85             66             29        0  26.6
# 2  32.0   Male      183             64              0        0  23.3
# 3  21.0   Male       89             66             23       94  28.1
# 4  33.0   Male      137             40             35      168  43.1
#
#    DiabetesPedigreeFunction  Outcome
# 0                     0.627        1
# 1                     0.351        0
# 2                     0.672        1
# 3                     0.167        0
# 4                     2.288        1

# %%
df.tail()
# Out:
#       Age  Gender  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 763  63.0    Male      101             76             48      180  32.9
# 764  27.0    Male      122             70             27        0  36.8
# 765  30.0  Female      121             72             23      112  26.2
# 766  47.0  Female      126             60              0        0  30.1
# 767  23.0  Female       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Outcome
# 763                     0.171        0
# 764                     0.340        0
# 765                     0.245        0
# 766                     0.349        1
# 767                     0.315        0

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 768 entries, 0 to 767
# Data columns (total 9 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Age                       763 non-null    float64
#  1   Gender                    768 non-null    object
#  2   Glucose                   768 non-null    int64
#  3   BloodPressure             768 non-null    int64
#  4   SkinThickness             768 non-null    int64
#  5   Insulin                   768 non-null    int64
#  6   BMI                       768 non-null    float64
#  7   DiabetesPedigreeFunction  768 non-null    float64
#  8   Outcome                   768 non-null    int64
# dtypes: float64(3), int64(5), object(1)
# memory usage: 54.1+ KB

# %%
df.isnull()
# Out:
#        Age  Gender  Glucose  BloodPressure  SkinThickness  Insulin    BMI  \
# 0    False   False    False          False          False    False  False
# 1    False   False    False          False          False    False  False
# 2    False   False    False          False          False    False  False
# 3    False   False    False          False          False    False  False
# 4    False   False    False          False          False    False  False
# ..     ...     ...      ...            ...            ...      ...    ...
# 763  False   False    False          False          False    False  False
# 764  False   False    False          False          False    False  False
# 765  False   False    False          False          False    False  False
# 766  False   False    False          False          False    False  False
# 767  False   False    False          False          False    False  False
#
#      DiabetesPedigreeFunction  Outcome
# 0                       False    False
# 1                       False    False
# 2                       False    False
# 3                       False    False
# 4                       False    False
# ..                        ...      ...
# 763                     False    False
# 764                     False    False
# 765                     False    False
# 766                     False    False
# 767                     False    False
#
# [768 rows x 9 columns]

# %%
df.isnull().sum()
# Out:
# Age                         5
# Gender                      0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Outcome                     0
# dtype: int64

# %%
df=pd.read_csv('/content/drive/MyDrive/diabetes (1).csv')
mean_Age=df['Age'].mean()
df['Age'].fillna(mean_Age,inplace=True)

# %%
df.isnull().sum()
# Out:
# Age                         0
# Gender                      0
# Glucose                     0
# BloodPressure               0
# SkinThickness               0
# Insulin                     0
# BMI                         0
# DiabetesPedigreeFunction    0
# Outcome                     0
# dtype: int64

# %%
plt.figure()
plt.hist(df['Age'],bins=10)
plt.xlabel('values')
plt.ylabel('frequency')
plt.title('Histogram')
plt.show()

# %%
plt.plot(df['BMI'],df['BMI'])
plt.xlabel('X')
plt.ylabel('Y')
plt.title('line plot')
# Out:
# Text(0.5, 1.0, 'line plot')

# %%
columns_to_normalize = ['Age']

min_max_scaler = MinMaxScaler()
df[columns_to_normalize] = min_max_scaler.fit_transform(df[columns_to_normalize])

# %%
df
# Out:
#           Age  Gender  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    0.483333    Male      148             72             35        0  33.6
# 1    0.166667    Male       85             66             29        0  26.6
# 2    0.183333    Male      183             64              0        0  23.3
# 3    0.000000    Male       89             66             23       94  28.1
# 4    0.200000    Male      137             40             35      168  43.1
# ..        ...     ...      ...            ...            ...      ...   ...
# 763  0.700000    Male      101             76             48      180  32.9
# 764  0.100000    Male      122             70             27        0  36.8
# 765  0.150000  Female      121             72             23      112  26.2
# 766  0.433333  Female      126             60              0        0  30.1
# 767  0.033333  Female       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Outcome
# 0                       0.627        1
# 1                       0.351        0
# 2                       0.672        1
# 3                       0.167        0
# 4                       2.288        1
# ..                        ...      ...
# 763                     0.171        0
# 764                     0.340        0
# 765                     0.245        0
# 766                     0.349        1
# 767                     0.315        0
#
# [768 rows x 9 columns]

# %%
df
# Out:
#       Age  Gender  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    50.0    Male      148             72             35        0  33.6
# 1    31.0    Male       85             66             29        0  26.6
# 2    32.0    Male      183             64              0        0  23.3
# 3    21.0    Male       89             66             23       94  28.1
# 4    33.0    Male      137             40             35      168  43.1
# ..    ...     ...      ...            ...            ...      ...   ...
# 763  63.0    Male      101             76             48      180  32.9
# 764  27.0    Male      122             70             27        0  36.8
# 765  30.0  Female      121             72             23      112  26.2
# 766  47.0  Female      126             60              0        0  30.1
# 767  23.0  Female       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Outcome
# 0                       0.627        1
# 1                       0.351        0
# 2                       0.672        1
# 3                       0.167        0
# 4                       2.288        1
# ..                        ...      ...
# 763                     0.171        0
# 764                     0.340        0
# 765                     0.245        0
# 766                     0.349        1
# 767                     0.315        0
#
# [768 rows x 9 columns]

# %%
from scipy import stats
ZScore=stats.zscore(df[['BMI']])
ZScore
# Out:
#           BMI
# 0    0.204013
# 1   -0.684422
# 2   -1.103255
# 3   -0.494043
# 4    1.409746
# ..        ...
# 763  0.115169
# 764  0.610154
# 765 -0.735190
# 766 -0.240205
# 767 -0.202129
#
# [768 rows x 1 columns]

# %%
encoder=OrdinalEncoder()
df['Ordinal_encoding']=encoder.fit_transform(df[['Gender']])

# %%
df
# Out:
#       Age  Gender  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    50.0    Male      148             72             35        0  33.6
# 1    31.0    Male       85             66             29        0  26.6
# 2    32.0    Male      183             64              0        0  23.3
# 3    21.0    Male       89             66             23       94  28.1
# 4    33.0    Male      137             40             35      168  43.1
# ..    ...     ...      ...            ...            ...      ...   ...
# 763  63.0    Male      101             76             48      180  32.9
# 764  27.0    Male      122             70             27        0  36.8
# 765  30.0  Female      121             72             23      112  26.2
# 766  47.0  Female      126             60              0        0  30.1
# 767  23.0  Female       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Outcome  Ordinal_encoding
# 0                       0.627        1               1.0
# 1                       0.351        0               1.0
# 2                       0.672        1               1.0
# 3                       0.167        0               1.0
# 4                       2.288        1               1.0
# ..                        ...      ...               ...
# 763                     0.171        0               1.0
# 764                     0.340        0               1.0
# 765                     0.245        0               0.0
# 766                     0.349        1               0.0
# 767                     0.315        0               0.0
#
# [768 rows x 10 columns]

# %%
label_encoder = LabelEncoder()
df['Age_encoder'] = label_encoder.fit_transform(df['Gender'])

# %%
df
# Out:
#           Age  Gender  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0    0.483333    Male      148             72             35        0  33.6
# 1    0.166667    Male       85             66             29        0  26.6
# 2    0.183333    Male      183             64              0        0  23.3
# 3    0.000000    Male       89             66             23       94  28.1
# 4    0.200000    Male      137             40             35      168  43.1
# ..        ...     ...      ...            ...            ...      ...   ...
# 763  0.700000    Male      101             76             48      180  32.9
# 764  0.100000    Male      122             70             27        0  36.8
# 765  0.150000  Female      121             72             23      112  26.2
# 766  0.433333  Female      126             60              0        0  30.1
# 767  0.033333  Female       93             70             31        0  30.4
#
#      DiabetesPedigreeFunction  Outcome  Age_encoder
# 0                       0.627        1            1
# 1                       0.351        0            1
# 2                       0.672        1            1
# 3                       0.167        0            1
# 4                       2.288        1            1
# ..                        ...      ...          ...
# 763                     0.171        0            1
# 764                     0.340        0            1
# 765                     0.245        0            0
# 766                     0.349        1            0
# 767                     0.315        0            0
#
# [768 rows x 10 columns]
